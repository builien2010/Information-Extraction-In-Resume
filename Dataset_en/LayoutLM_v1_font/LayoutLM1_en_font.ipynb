# %%
# !nvidia-smi
# Out:
# Fri Oct  1 07:28:54 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P8    31W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Resumes/LayoutLM_font"
# !ls
# Out:
# /content/drive/MyDrive/Resumes/LayoutLM_font
# 'Bản sao của LayoutLM_22_05_2021.ipynb'       LayoutLM_04_05_2021.ipynb
# 'Bản sao của LM_font_demo_28_04_2021.ipynb'   LayoutLM_22_05_2021.ipynb
#  fixbug.ipynb				      LM_font_demo_27_04_2021.ipynb
#  layoutlm				      LM_font_demo_28_04_2021.ipynb

# %%
# %cd 'layoutlm'
# !ls
# Out:
# /content/drive/MyDrive/Resumes/LayoutLM_font/layoutlm
# examples  layoutlm  mypy.ini  README.md  run.txt  setup.py

# %%
# !pip install .
# Out:
# Processing /content/drive/MyDrive/Resumes/LayoutLM_font/layoutlm
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#      |████████████████████████████████| 635 kB 2.3 MB/s
# ...
#      |████████████████████████████████| 195 kB 43.6 MB/s
# ...
#      |████████████████████████████████| 5.5 MB 39.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 42.0 MB/s
# ...
#      |████████████████████████████████| 5.6 MB 12.5 MB/s
# ...
#      |████████████████████████████████| 895 kB 39.4 MB/s
# ...
#   Created wheel for layoutlm: filename=layoutlm-0.0-py3-none-any.whl size=16988 sha256=eed4abff774801e085db165f21af93d307c4fbcf0066fda52b65fe437db43e18
# ...

# %%
import os
import subprocess

# from pdf2image import convert_from_path
from PIL import Image
# import pytesseract

# %%
os.chdir('examples/seq_labeling')

# %%
# !python preprocess.py --data_dir data/training_data/annotations \
                                    --data_split train \
                                    --output_dir data \
                                    --model_name_or_path bert-base-uncased \
                                    --max_len 510

# %%
# !cat data/train.txt | cut -d$'\t' -f 2 | grep -v "^$"| sort | uniq > data/labels.txt

# %%
!%% bash
# !ls data
# Out:
# /bin/bash: line 0: fg: no job control
# dataset_tong_hop  train_box.txt      train_image.txt.tmp  train.txt.tmp
# labels.txt	  train_box.txt.tmp  training_data
# testing_data	  train_image.txt    train.txt

# %%
# !cat data/labels.txt
# Out:
# O
# S-COMPANY_DATE
# S-COMPANY_NAME
# S-EMAIL
# S-GRADE
# S-MAJOR
# S-NAME
# S-PHONE
# S-POSITION
# S-PROJECT_NAME
# S-SCHOOL_DATE
# S-SCHOOL_NAME

# %%
# !ls
# Out:
# data	data_cv1_vn  output_1	    preprocess.sh  run_seq_labeling.py
# data_1	data_vn      preprocess.py  runs

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/Resumes/LayoutLM_font"
# !ls
# %cd 'layoutlm'
# !ls
os.chdir('examples/seq_labeling')
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Resumes/LayoutLM_font
# 'Bản sao của LayoutLM_22_05_2021.ipynb'       LayoutLM_04_05_2021.ipynb
# 'Bản sao của LM_font_demo_28_04_2021.ipynb'   LayoutLM_1_10_2021.ipynb
#  fixbug.ipynb				      LM_font_demo_27_04_2021.ipynb
#  layoutlm				      LM_font_demo_28_04_2021.ipynb
# /content/drive/MyDrive/Resumes/LayoutLM_font/layoutlm
# examples  layoutlm  mypy.ini  README.md  run.txt  setup.py
# data	data_cv1_vn  output    preprocess.py  runs
# data_1	data_vn      output_1  preprocess.sh  run_seq_labeling.py

# %%
! python run_seq_labeling.py  --data_dir data \
                            --model_type layoutlm \
                            --model_name_or_path /content/drive/MyDrive/Resumes/layoutlm-base-uncased \
                            --do_lower_case \
                            --max_seq_length 512 \
                            --do_train \
                            --num_train_epochs 20 \
                            --logging_steps 10 \
                            --save_steps -1 \
                            --output_dir output \
                            --labels data/labels.txt \
                            --per_gpu_train_batch_size 4 \
                            --per_gpu_eval_batch_size 4 \
                            --seed 12
# Out:
# Streaming output truncated to the last 5000 lines.
# padding_length:  183
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  31
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  0
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  460
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  0
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  431
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  0
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  485
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  0
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  385
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  0
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  476
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  181
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  386
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/Resumes/LayoutLM_font"
# !ls
# %cd 'layoutlm'
# !ls
os.chdir('examples/seq_labeling')
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Resumes/LayoutLM_font
# 'Bản sao của LayoutLM_22_05_2021.ipynb'       LayoutLM_04_05_2021.ipynb
# 'Bản sao của LM_font_demo_28_04_2021.ipynb'   LayoutLM_1_10_2021.ipynb
#  fixbug.ipynb				      LM_font_demo_27_04_2021.ipynb
#  layoutlm				      LM_font_demo_28_04_2021.ipynb
# /content/drive/MyDrive/Resumes/LayoutLM_font/layoutlm
# examples  layoutlm  mypy.ini  README.md  run.txt  setup.py
# data	data_cv1_vn  output    preprocess.py  runs
# data_1	data_vn      output_1  preprocess.sh  run_seq_labeling.py

# %%
# !python preprocess.py --data_dir data/testing_data/annotations \
                                    --data_split test \
                                    --output_dir data \
                                    --model_name_or_path bert-base-uncased \
                                    --max_len 510

# %%
# !python run_seq_labeling.py  --data_dir data \
                              --model_type layoutlm \
                              --model_name_or_path output \
                              --do_lower_case \
                              --max_seq_length 512 \
                              --output_dir output \
                              --labels data/labels.txt \
                              --per_gpu_eval_batch_size 1 \
                              --do_predict \
                              --seed 12 \
# Out:
# funsd
# funsd:
#
#
#
#
#
# padding_length:  118
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  271
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  118
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  42
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  174
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  118
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  0
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  472
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  49
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  479
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  0
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  472
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  174
# len(font_size):  512
# len(font_type):  512
#
# padding_length:  218
# len(font_size):  512
# ...
