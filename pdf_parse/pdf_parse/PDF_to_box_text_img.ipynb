# %%
# !pip install -r requirements.txt
# !apt-get install poppler-utils

# %%
# %cd '/content/drive/MyDrive/Resumes_Project/preprocess/src/annotation'
# !ls

# %% [markdown]
# ### Lấy thông tin box, text từ file pdf của CV tiếng việt

# %%
# !python pdf_bboxes.py --input_pdf "/content/drive/MyDrive/Resumes_Project/preprocess/dataset/CV_Vietnam/Vietnamses/" \
                    --output_dir "/content/drive/MyDrive/Resumes_Project/preprocess/dataset/annotation_vietnam/"  \
                    --csv_folder "csv/" \
                    --img_folder "img/" \
                    --img_origin "img_origin/"  \
                    --json_folder "json/"

# %% [markdown]
# ### Lấy thông tin box, text từ file pdf của CV tiếng anh

# %%
# !python pdf_bboxes.py --input_pdf "/content/drive/MyDrive/Resumes_Project/preprocess/dataset/CV_Vietnam/English/" \
                    --output_dir "/content/drive/MyDrive/Resumes_Project/preprocess/dataset/annotation_english/"  \
                    --csv_folder "csv/" \
                    --img_folder "img/" \
                    --img_origin "img_origin/" \
                    --json_folder "json/"
