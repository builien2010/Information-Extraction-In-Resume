# %%
# %cd "/content/drive/MyDrive/CV/CV/Dataset3/LayoutLMv2_Resumes_vn"
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1uj0SLVWeY2nKNo-83gnSQF8KaLKpAEIa/CV/Dataset3/LayoutLMv2_Resumes_vn
# LayoutLMv2_resumes_vn.ipynb  unilm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd unilm/layoutlmft
# Out:
# /content/drive/.shortcut-targets-by-id/1uj0SLVWeY2nKNo-83gnSQF8KaLKpAEIa/CV/Dataset3/LayoutLMv2_Resumes_vn/unilm/layoutlmft

# %%
# !pip install -r requirements.txt
# !pip install -e .
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html, https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.7/index.html
# ...
# Obtaining file:///content/drive/.shortcut-targets-by-id/1uj0SLVWeY2nKNo-83gnSQF8KaLKpAEIa/CV/Dataset3/LayoutLMv2_Resumes_vn/unilm/layoutlmft
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Attempting uninstall: layoutlmft
#     Found existing installation: layoutlmft 0.1
#     Can't uninstall 'layoutlmft'. No files were found to uninstall.
#   Running setup.py develop for layoutlmft
# ...

# %%
# !pip install pyyaml==5.1

# %%
# !ls
# Out:
# data_vn     layoutlmft		 pyproject.toml    setup.cfg
# Data_vn_vn  layoutlmft.egg-info  README.md	   setup.py
# examples    Makefile		 requirements.txt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd "/content/drive/MyDrive/CV/CV/Dataset3/LayoutLMv2_Resumes_vn"
# %cd unilm/layoutlmft
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/.shortcut-targets-by-id/1uj0SLVWeY2nKNo-83gnSQF8KaLKpAEIa/CV/Dataset3/LayoutLMv2_Resumes_vn
# /content/drive/.shortcut-targets-by-id/1uj0SLVWeY2nKNo-83gnSQF8KaLKpAEIa/CV/Dataset3/LayoutLMv2_Resumes_vn/unilm/layoutlmft

# %%
# !python -m torch.distributed.launch --nproc_per_node=1 examples/run_funsd.py \
        --model_name_or_path microsoft/layoutlmv2-base-uncased \
        --output_dir output \
        --do_train \
        --do_predict \
        --max_steps 2000 \
        --warmup_ratio 0.01 \
        --per_device_train_batch_size 4 \
        --per_device_eval_batch_size 4 \
# Out:
# 10/01/2021 05:02:32 - WARNING - __main__ -   Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# ...

# %%
# !python -m torch.distributed.launch --nproc_per_node=1 examples/run_funsd.py \
        --model_name_or_path microsoft/layoutlmv2-base-uncased \
        --output_dir output \
        --do_predict \
        --max_steps 1 \
        --warmup_ratio 0.1 \
        --per_device_train_batch_size 4 \
        --per_device_eval_batch_size 4 \
# Out:
# 10/01/2021 04:50:49 - WARNING - __main__ -   Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# ...

# %%
# Dùng do_train 
# dùng do_train do_predict 
# dùng do_predict : lỗi
# dùng do_eval lỗi

# %%
# !python -m torch.distributed.launch --nproc_per_node=1 examples/run_funsd.py \
        --model_name_or_path microsoft/layoutlmv2-base-uncased \
        --output_dir output \
        --do_train \
        --do_predict \
        --max_steps 1 \
        --warmup_ratio 0.1 \
        --per_device_train_batch_size 4 \
        --per_device_eval_batch_size 4 \
# Out:
# 2021-06-22 05:17:38.672534: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 06/22/2021 05:17:43 - WARNING - __main__ -   Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# ...

# %%
# !python -m torch.distributed.launch --nproc_per_node=1 examples/run_funsd.py \
        --model_name_or_path microsoft/layoutlmv2-base-uncased \
        --output_dir output \
        --do_eval \
        --max_steps 1 \
        --warmup_ratio 0.1 \
        --per_device_train_batch_size 4 \
        --per_device_eval_batch_size 4 \
# Out:
# 2021-06-22 04:04:40.121557: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 06/22/2021 04:04:44 - WARNING - __main__ -   Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# ...
